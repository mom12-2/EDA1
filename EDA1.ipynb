# %% [markdown]
# Dataset: Synthetic data (manually typed lists).
# Goal: Reinforce the Matplotlib Object-Oriented canvas structure and introduce basic Seaborn styling to track how two different medications reduce pain over time.
#
# 1. Importing Libraries & Theming:
#
#         .Start by importing matplotlib.pyplot as plt and import seaborn as sns.
#
#         .New Skill: Before creating your plot, use Seaborn to instantly upgrade the visuals by setting a theme. Call sns.set_theme(style="darkgrid").

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid")

plt.plot()

plt.show()

# %% [markdown]
# 2. The Anatomy / Basic Plotting:
#
# .Create lists to track a 6-hour window.
#
# .hours = [1, 2, 3, 4, 5, 6]
#
# .Create two lists for the medications, representing reported pain levels on a scale of 0 to 10 (e.g., med_A_pain = [8, 6, 5, 3, 2, 2]).
#
# Set up your canvas using the Object-Oriented method: fig, ax = plt.subplots().
# Plot the data using ax.plot(hours, med_A_pain) and ax.plot(hours, med_B_pain).
#
# New Skill: Inside your ax.plot() calls, try adding markers and specific colors to differentiate the lines further (e.g., ax.plot(..., color='blue', marker='o', label='Medication A')).

# %% [markdown]
# 3. Basic Customization:
#
# .Instruct the canvas to display your metadata:
#
# .ax.set_title("Pain Level Over Time: Med A vs. Med B")
#
# .ax.set_xlabel("Hours Post-Dose")
#
# .ax.set_ylabel("Reported Pain Level (0-10)")
#
# Call ax.legend() so the viewer knows which line represents which medication.
# Finally, render the plot cleanly with plt.show().

# %%
hours = [1, 2, 3, 4, 5, 6]
med_A_pain = [8, 6, 5, 3, 2, 2]
med_B_pain = [8, 7, 6, 5, 4, 3]

fig, ax = plt.subplots()

ax.plot(hours, med_A_pain, color='blue', marker='o', label='Medication A')

ax.plot(hours, med_B_pain, color='blue', marker='s', label='Medication B')

ax.set_title("Pain Levels Over 6 Hours")
ax.set_xlabel("Hours")
ax.set_ylabel("Pain Level")

ax.set_title("Pain Level Over Time: Med A vs. Med B")

ax.set_xlabel("Hours Post-Dose")

ax.set_ylabel("Reported Pain Level (0-10)")
ax.legend()
plt.show()

# %% [markdown]
# 4. Explain each of the graphs in details(both Khmer and English)

# %% [markdown]
# Over a 6-hour period, this graph shows how two medications affect a patient’s pain level after taking a dose.
#
# At the beginning, both Medication A and Medication B start at the same pain level of 8, meaning the patient is in strong discomfort right after taking the medicine.
#
# For Medication A, the change is fast and consistent. The pain drops quickly within the first few hours, going from 8 down to 3 by Hour 4, and finally reaching a very low level of 2 by Hour 5. After that, it stays stable. This shows that Medication A acts quickly and provides strong, reliable pain relief.
#
# For Medication B, the improvement is slower and more gradual. Instead of a sharp drop, the pain decreases step by step over time, and even after 6 hours, the pain is still at level 3. This means the patient still feels some discomfort, and the medication is not as strong in the short term.
#
# Overall, the graph shows a clear difference between the two treatments: Medication A delivers fast and powerful relief, while Medication B works more slowly and provides milder results.

# %% [markdown]
# ក្នុងរយៈពេល ៦ ម៉ោងក្រោយលេបថ្នាំ ក្រាហ្វនេះបង្ហាញពីការប្រៀបធៀបរវាង Medication A និង Medication B ក្នុងការបន្ថយកម្រិតការឈឺ។
#
# នៅដំបូង ទាំងថ្នាំ A និង B ចាប់ផ្តើមនៅកម្រិតការឈឺ 8 ដែលមានន័យថាអ្នកជំងឺកំពុងមានការឈឺខ្លាំងដូចគ្នា។
#
# សម្រាប់ Medication A ការបន្ថយការឈឺកើតឡើងលឿន និងស្ថិរភាព។ កម្រិតការឈឺធ្លាក់ចុះយ៉ាងរហ័សពី 8 ទៅ 3 ក្នុងរយៈពេលប៉ុន្មានម៉ោងដំបូង ហើយបន្តធ្លាក់ដល់ 2 នៅម៉ោងទី 5 ហើយនៅតែស្ថិតនៅកម្រិតទាបនោះ។ នេះបង្ហាញថា ថ្នាំ A មានប្រសិទ្ធភាពលឿន និងខ្លាំងក្នុងការបន្ថយការឈឺ។
#
# ចំណែកឯ Medication B វាបន្ថយការឈឺយឺតជាង។ ការឈឺថយចុះបន្តិចម្តងៗពី 8 ទៅ 3 នៅចុងម៉ោងទី 6 ដែលមានន័យថា អ្នកជំងឺនៅតែមានការឈឺខ្លះ។ វាបង្ហាញថា ថ្នាំ B មានប្រសិទ្ធភាព តែយឺត និងខ្សោយជាងថ្នាំ A។
#
# សរុបមក ក្រាហ្វនេះបង្ហាញថា Medication A មានប្រសិទ្ធភាពលឿន និងខ្លាំងជាង ខណៈដែល Medication B ធ្វើការយឺត និងបន្ថយការឈឺបានតិចជាង។

# %% [markdown]
# Over a 6-hour period, this graph compares how two medications reduce a patient’s pain level after taking a dose.
#
# Both Medication A and Medication B start at a pain level of 8, showing strong initial pain. Medication A reduces pain quickly and consistently, dropping to 2 by Hour 5 and staying low. Medication B decreases pain more slowly and only reaches 3 by Hour 6.
#
# Overall, Medication A is faster and more effective, while Medication B works more slowly with weaker results.
